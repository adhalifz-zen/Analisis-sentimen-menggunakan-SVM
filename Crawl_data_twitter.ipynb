# %% [markdown]
# <a href="https://colab.research.google.com/github/adhalifz-zen/Analisis-sentimen-menggunakan-SVM/blob/main/Crawl_data_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crawl Data Twitter > 2000 Tweets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Twitter Auth Token

twitter_auth_token = 'edcc7add49e8384a6f36e3664dbb8925f4009221' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Ign:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# Crawl Data

filename = 'kendaraanlistrik.csv'
search_keyword = 'kendaraan listrik since:2023-10-03 until:2024-10-03 lang:id'
limit = 1500

# !npx -y tweet-harvest@2.6.1 -o "{kendaraan listrik}" -s "{kendaraan listrik}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: kendaraan listrik since:2023-10-03 until:2024-10-03 lang:id
#
#  (3)Created new directory: /content/tweets-data
#
#
# Your tweets saved to: /content/tweets-data/kendaraanlistrik.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/kendaraanlistrik.csv
# Total tweets saved: 39
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/kendaraanlistrik.csv
# Total tweets saved: 58
#
# -- Scrolling... (1) (2)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = "/content/drive/MyDrive/SKRIPSI/kendaraanlistrik (2).csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1841619712553451985  Wed Oct 02 23:22:09 +0000 2024               0
# 1     1841615001469206764  Wed Oct 02 23:03:26 +0000 2024              14
# 2     1841610369812595140  Wed Oct 02 22:45:02 +0000 2024             240
# 3     1841363651829317946  Wed Oct 02 16:05:31 +0000 2024               0
# 4     1841476370746224957  Wed Oct 02 13:52:34 +0000 2024               7
# ...                   ...                             ...             ...
# 1500  1829174196846682567  Thu Aug 29 15:08:07 +0000 2024               0
# 1501  1829170922986844364  Thu Aug 29 14:55:07 +0000 2024               0
# 1502  1829170261306036608  Thu Aug 29 14:52:29 +0000 2024               0
# 1503  1829128296912871522  Thu Aug 29 14:47:19 +0000 2024               4
# 1504  1829164785151422748  Thu Aug 29 14:30:43 +0000 2024               0
#
#                                               full_text               id_str  \
# ...

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 1505.

# %%
# prompt: ambil kolom full_text

df = df['full_text']
df
# Out:
# 0       Mercedes &amp; BMW Desak Jerman Tolak Tarif Ke...
# 1       Presiden Jokowi menegaskan bahwa IKN akan meng...
# 2       Dah jelas ya knp PEMERINTAH ngotot kendaraan l...
# 3       @SoftWarNews Ooooooo pak luhut kemaren nyuruh ...
# 4       Moeldoko Tetap Kawal Proyek Baterai Kendaraan ...
#                               ...
# 1500    Samsung SDI dan GM Jalin Kerja Sama Bakal Bang...
# 1501    BRARTI YOONGI LOE YANG KRIMINAL ITU HARUS ADA ...
# 1502    Pemerintah membantu 34 unit motor trail elektr...
# 1503    @titobawono @gagitugung @PernebangRoket Lah ti...
# 1504    2006 &amp; 2008 pergi ke Tembagapura di Papua ...
# Name: full_text, Length: 1505, dtype: object

# %%
# prompt: simpan hasilnya ke excel

# Save the DataFrame to an Excel file
excel_file_path = "/content/drive/MyDrive/SKRIPSI/kendaraanlistrik.xlsx"  # Specify the desired path and filename for the Excel file
df.to_excel(excel_file_path, index=False)  # Save to Excel, set index=False to avoid saving the index column
